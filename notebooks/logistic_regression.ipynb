# %%
# import the libraries and utilities
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

import numpy as np
from sklearn.linear_model import LogisticRegression

# Simple Binary Classification Dataset

# X is the 2D array of Features age and income of 5 individuals
X_binary = np.array([
    [25, 30000],  
    [45, 80000],  
    [18, 20000],  
    [55, 95000],  
    [30, 40000]   
])

# y is Labels which are 0 or 1. trying to classify  0 = Did Not Buy, 1 = Did Buy
y_binary = np.array([0, 1, 0, 1, 0]) 

# Logistic Regression Model
model = LogisticRegression(solver='liblinear', random_state=1)

# Train the LR Model
# The model learns the relationship between X (Age, Income) and y (Buy 1/Not Buy 0)
model.fit(X_binary, y_binary)

# Make a Prediction of model on a new data point

# New person: 40 years, 65,000 income
X_new = np.array([[40, 65000]])

# Predict the class 0 or 1
predicted_class = model.predict(X_new)

# Predict the probability , probability of being class 1
predicted_proba = model.predict_proba(X_new)

# Results 
print("Simple Logistic Regression Results")
print(f"Features (Age, Income) for prediction: {X_new.flatten()}")
print(f"Predicted Class (0, 1): {predicted_class[0]}")
print(f"Predicted Probability (0 and 1): {predicted_proba.round(3)}")
# Out:
# Simple Logistic Regression Results
# Features (Age, Income) for prediction: [   40 65000]
# Predicted Class (0, 1): 1
# Predicted Probability (0 and 1): [[0.271 0.729]]

# %%
# Visualization 

plt.figure(figsize=(8, 6))

# The scatter plot uses the first feature Age vs Income. The 'c=y_binary' points based on their class 0 or 1.
scatter = plt.scatter(X_binary[:, 0], X_binary[:, 1], 
                      c=y_binary, 
                      cmap='coolwarm', 
                      s=100,           
                      edgecolors='k')  

# Add labels and title
plt.xlabel('Feature 1: Age')
plt.ylabel('Feature 2: Income')
plt.title('Simple Binary Classification Data')

# Add a legend to show which color corresponds to which class
legend1 = plt.legend(*scatter.legend_elements(),
                     loc="upper left", title="Class")

plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
# Challenge classification task by using the Iris dataset 
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
iris = load_iris()
# Use all four features likeSepal Length, Sepal Width, Petal Length, Petal Width X has the features, y has the labels
# and use only 2 classes for binary classification
X = iris.data[iris.target != 2]
y = iris.target[iris.target != 2]

# Split Data into Training 70 % and Testing Sets 30% random_state ensures the split is the same every time
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1
)

# Model Training
# Initialize the Logistic Regression model and use solver 'liblinear'for small datasets
model = LogisticRegression(solver='liblinear', random_state=1)

# Train the model using the training data
model.fit(X_train, y_train)


# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluation with Sklearn Metrics

print("\n Model Evaluation Binary Iris Dataset ")

# Accuracy Score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy Score: {accuracy:.4f} ({accuracy:.2f}%)")

# Confusion Matrix shows where the model made correct and incorrect predictions
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Classification Report provides Precision, Recall, and F1-score for each class
class_report = classification_report(y_test, y_pred, target_names=iris.target_names[:2])
print("\nClassification Report:")
print(class_report)
# Out:
#  Model Evaluation Binary Iris Dataset
# Accuracy Score: 1.0000 (1.00%)
#
# Confusion Matrix:
# [[14  0]
#  [ 0 16]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       1.00      1.00      1.00        16
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
# Breast Cancer Wisconsin Dataset Classification Task
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
X, y = data.data, data.target

# Split Data into Training 70 % and Testing Sets 30%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state =1)

# Initialize the Logistic Regression model
model = LogisticRegression(solver='liblinear', random_state=1)

# Train the model using the training data
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluation with Sklearn Metrics
print("\n Model Evaluation Breast Cancer Dataset ")

# Accuracy Score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy Score: {accuracy:.4f} ({accuracy:.2f}%)")

# Confusion Matrix shows where the model made correct and incorrect predictions
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# Classification Report provides Precision, Recall, and F1-score for each class
class_report = classification_report(y_test, y_pred, target_names=data.target_names[:2])
print("\nClassification Report:")
print(class_report)
# Out:
#  Model Evaluation Breast Cancer Dataset
# Accuracy Score: 0.9532 (0.95%)
#
# Confusion Matrix:
# [[ 57   6]
#  [  2 106]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    malignant       0.97      0.90      0.93        63
#       benign       0.95      0.98      0.96       108
#
#     accuracy                           0.95       171
#    macro avg       0.96      0.94      0.95       171
# weighted avg       0.95      0.95      0.95       171
